# %%
import importlib
import mortgage
import pandas as pd
import numpy as np
mortgage = importlib.reload(mortgage)

# %%
loan = 1.71 * 10**6
n_years = 13
n_months = 12 * n_years

const_loan = mortgage.Loan((1.71*10**6)*0.34, 3.13/100, 120)
agah_loan = mortgage.Loan((1.71*10**6)*0.33, 2.55/100, 120)
prime_loan = mortgage.Loan((1.71*10**6)*0.33, 0.8/100, 360)
work_loan = mortgage.Loan(100*10**3, 3.1/100, 84)

loans = [
    work_loan,
    const_loan,
    agah_loan,
    prime_loan,
]

mortgage.shptizer_multiple(loans)
# Out:
#              fund     interest         total       balance
# 0    10720.810932  3350.155833  14070.966765  1.810000e+06
# 1    10744.055965  3326.910799  14070.966765  1.799279e+06
# 2    10767.355520  3303.611245  14070.966765  1.788535e+06
# 3    10790.709727  3280.257038  14070.966765  1.777768e+06
# 4    10814.118718  3256.848047  14070.966765  1.766977e+06
# 5    10837.582626  3233.384138  14070.966765  1.756163e+06
# 6    10861.101585  3209.865180  14070.966765  1.745325e+06
# 7    10884.675726  3186.291039  14070.966765  1.734464e+06
# 8    10908.305183  3162.661582  14070.966765  1.723580e+06
# 9    10931.990091  3138.976674  14070.966765  1.712671e+06
# 10   10955.730582  3115.236183  14070.966765  1.701739e+06
# 11   10979.526793  3091.439972  14070.966765  1.690784e+06
# 12   11003.378856  3067.587909  14070.966765  1.679804e+06
# 13   11027.286908  3043.679857  14070.966765  1.668801e+06
# 14   11051.251084  3019.715681  14070.966765  1.657773e+06
# ...
